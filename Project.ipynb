# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # Top 5 data from the table

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # Last 5 data from the table

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %% [markdown]
# # Checking for NaN values

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # Information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# # Description of the Dataset

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# # Value Counts

# %%
df["Sex"].value_counts()
# Out:
# M    725
# F    193
# Name: Sex, dtype: int64

# %%
df["ChestPainType"].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
df["FastingBS"].value_counts()
# Out:
# 0    704
# 1    214
# Name: FastingBS, dtype: int64

# %%
df["RestingECG"].value_counts()
# Out:
# Normal    552
# LVH       188
# ST        178
# Name: RestingECG, dtype: int64

# %%
df["ExerciseAngina"].value_counts()
# Out:
# N    547
# Y    371
# Name: ExerciseAngina, dtype: int64

# %%
df["ST_Slope"].value_counts()
# Out:
# Flat    460
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64

# %%
df["HeartDisease"].value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %% [markdown]
# # We check for the people who are suffering from heart disease

# %%
df[df["HeartDisease"]==1]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 11    58   M           ATA        136          164          0         ST
# 13    49   M           ASY        140          234          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # These is the bar graph for ECG

# %%
sns.countplot(df['RestingECG'])
plt.title("ECG")
# Out:
# Text(0.5, 1.0, 'ECG')

# %% [markdown]
# # This the pie chart showing the chest pain

# %%
df["ChestPainType"].value_counts().plot.pie(autopct="%1.2f%%",explode=(0,0,0,0))
plt.title("Chest Pain")
plt.show()

# %% [markdown]
# # This is a count plot for Age

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df,y="Age")
plt.grid(True)

# %% [markdown]
# # Bar Graph with respect to age and cholesterol

# %%
x = df["Age"]
y = df["Cholesterol"]
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.bar(x,y)
# Out:
# <BarContainer object of 918 artists>

# %% [markdown]
# # Data of the people who are suffering from heart disease with respect to gender

# %%
df[(df["Sex"]=="M")&(df["HeartDisease"]==1)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 8     37   M           ASY        140          207          0     Normal
# 11    58   M           ATA        136          164          0         ST
# 13    49   M           ASY        140          234          0     Normal
# 16    38   M           ASY        110          196          0     Normal
# 18    60   M           ASY        100          248          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 908   63   M           ASY        140          187          0        LVH
# 911   59   M           ASY        164          176          1        LVH
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df[(df["Sex"]=="F")&(df["HeartDisease"]==1)].count()
# Out:
# Age               50
# Sex               50
# ChestPainType     50
# RestingBP         50
# Cholesterol       50
# FastingBS         50
# RestingECG        50
# MaxHR             50
# ExerciseAngina    50
# Oldpeak           50
# ST_Slope          50
# HeartDisease      50
# dtype: int64

# %% [markdown]
# # Line plot of age with respect to st_slope

# %%
y = df["Age"]
x = df["ST_Slope"]
sns.lineplot(x,y)
plt.grid(True) 
plt.show()# positive corrilation

# %% [markdown]
# # Boxplot of cholesterol

# %%
np.quantile(df["Cholesterol"],0.25)
# Out:
# 173.25

# %%
np.quantile(df["Cholesterol"],0.75)
# Out:
# 267.0

# %%
sns.boxplot(data=df,x="Cholesterol")
# Out:
# <AxesSubplot:xlabel='Cholesterol'>

# %% [markdown]
# # People with Normal ECG but still suffering from heart disease

# %%
df[(df["RestingECG"]=="Normal")&(df["HeartDisease"]==1)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 13    49   M           ASY        140          234          0     Normal
# 16    38   M           ASY        110          196          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 909   63   F           ASY        124          197          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df[(df["RestingECG"]=="ST")&(df["HeartDisease"]==1)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 11    58   M           ATA        136          164          0         ST
# 33    41   M           ASY        130          172          0         ST
# 41    54   F           NAP        130          294          0         ST
# 57    58   M           NAP        130          213          0         ST
# 59    52   M           ASY        112          342          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 610   54   F           ASY        127          333          1         ST
# 612   55   M           ASY        122          223          1         ST
# 725   55   F           ASY        180          327          0         ST
# 897   55   F           ASY        128          205          0         ST
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # Conclusion :
#         In the dataset there is an average of 53.5 years old people in data with youngest is 28 years old and oldest is 77.there are most of the people with restingBP with 132.There are normal cholesterol 198.7 in dataset.
#         In above dataset we can see there are 918 people and 518 people that are suffering for the heart disease .there are most male that have heart disease in the dataset .There are only 50 female in the dataset that are suffering heart disease .In above dataset we can conclude that data 392 people that are suffering from heart disease due to ASY type of Chest pain.There are 285 people in the dataset which have normal RestingECG but still suffer from heart disease.

# %% [markdown]
# # Result :
#         From the above we can say that most of the mails suffer from the heart disease .
#       If we have RestingECG of ST type you have very high chance of having a heart disease.
#           we can say that even if you have normalECG that dosent mean that you dont have heart       disease you still need to check other things.
